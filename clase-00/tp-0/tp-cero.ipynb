# %%
# %matplotlib inline
import numpy as np
from scipy import ndimage
import imageio

# Para visualizar
import matplotlib.pyplot as plt

# %%
# Cargamos imagen
lena = np.array(imageio.imread('data/lena3.tif'))

# %%
# Mostramos imágen
plt.imshow(lena)

# %%
flipped_lenas = [np.flipud(lena), np.fliplr(lena)]

fig, ax = plt.subplots(1, 2, figsize=(10,15))

for i, lena in enumerate(flipped_lenas):
    ax[i].imshow(lena)
    
plt.show()

# %%
rotation_angles = [45*i for i in range(8)]

#rotation with reshape
fig, ax = plt.subplots(1, len(rotation_angles), figsize=(20,30))
for i, angle in enumerate(rotation_angles):
    ax[i].imshow(ndimage.rotate(lena, angle, reshape=True))
    
plt.show()

#rotation without reshape
fig, ax = plt.subplots(1, len(rotation_angles), figsize=(20,30))
for i, angle in enumerate(rotation_angles):
    ax[i].imshow(ndimage.rotate(lena, angle, reshape=False))
    
plt.show()

# %%
# Manipulamos, en este caso es un recorte de la imagen
alt_lena = lena[200:300, 200:300]

imageio.imwrite('data/alt_lena.tif', alt_lena)

# %%
plt.imshow(imageio.imread('data/alt_lena.tif'))
