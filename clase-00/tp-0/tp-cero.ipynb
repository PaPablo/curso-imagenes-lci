# %%
# %matplotlib inline
import numpy as np
from scipy import ndimage
from PIL import Image

# Para visualizar
import matplotlib.pyplot as plt

# %%
# Cargamos imagen
face = np.array(Image.open('data/face.png'))

# %%
# Mostramos imágen
plt.imshow(face)

# %%
flipped_faces = [np.flipud(face), np.fliplr(face)]

fig, ax = plt.subplots(1, 2, figsize=(10,15))

for i, face in enumerate(flipped_faces):
    ax[i].imshow(face)
    
plt.show()

# %%
rotation_angles = [45*i for i in range(8)]

#rotation with reshape
fig, ax = plt.subplots(1, len(rotation_angles), figsize=(20,30))
for i, angle in enumerate(rotation_angles):
    ax[i].imshow(ndimage.rotate(face, angle, reshape=True))
    
plt.show()

#rotation without reshape
fig, ax = plt.subplots(1, len(rotation_angles), figsize=(20,30))
for i, angle in enumerate(rotation_angles):
    ax[i].imshow(ndimage.rotate(face, angle, reshape=False))
    
plt.show()

# %%
# Manipulamos, en este caso es un recorte de la imagen
alt_face = face[:500, :500]

Image.fromarray(alt_face).save('data/alt-face.png')
